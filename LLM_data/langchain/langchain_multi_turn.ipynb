# %%
# from openai import OpenAI  # 주석처리
# from dotenv import load_dotenv
# import os

# load_dotenv()
# api_key = os.getenv("OPENAI_API_KEY")  # 환경 변수에서 API 키 가져오기
# client = OpenAI(api_key=api_key)  # 오픈AI 클라이언트의 인스턴스 생성

# /// 위의 3줄을 랭체인에서는 아래 3줄로 처리할 수 있다 -----------------------

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

llm = ChatOpenAI(model="gpt-4o")  # ChatOpenAI 클래스의 인스턴스 생성


# def get_ai_response(messages):
#     response = client.chat.completions.create(
#         model="gpt-4o",  # 응답 생성에 사용할 모델 지정
#         temperature=0.9,  # 응답 생성에 사용할 temperature 설정
#         messages=messages,  # 대화 기록을 입력으로 전달
#     )
#     return response.choices[0].message.content  # 생성된 응답의 내용 반환

messages = [
    # {"role": "system", "content": "너는 사용자를 도와주는 상담사야."},  # 초기 시스템 메시지
    SystemMessage("너는 사용자를 도와주는 상담사야."),  # 초기 시스템 메시지
]

while True:
    user_input = input("사용자: ")  # 사용자 입력 받기

    if user_input == "exit":  # ② 사용자가 대화를 종료하려는지 확인인
        break
    
    messages.append(
        # {"role": "user", "content": user_input} # 주석처리
        HumanMessage(user_input)
    )  # 사용자 메시지를 대화 기록에 추가 
    
    # ai_response = get_ai_response(messages)  # 주석처리
    ai_response = llm.invoke(messages)  # 대화 기록을 기반으로 AI 응답 가져오기
    messages.append(
        # {"role": "assistant", "content": ai_response} # 주석처리
        ai_response
    )  # AI 응답 대화 기록에 추가하기

    print("AI: " + ai_response.content)  # AI 응답 출력
# Out:
# AI: 홍길동은 조선 시대의 가공의 인물로, 하층민의 고난과 억압을 극복하고 정의를 실현하는 이야기 속의 영웅입니다. 그는 본래 허균의 소설 "홍길동전"의 주인공으로, 권력과 부패에 맞서 싸우며, 약자들을 도와주는 의적으로 그려집니다. 홍길동은 한국 문학사에서 매우 중요한 존재이며, 많은 사람들이 그의 이야기를 통해 정의와 평등의 가치를 배우고 있습니다. 혹시 홍길동과 관련된 특정한 질문이 있으신가요?
# AI: 홍길동은 허균의 소설 "홍길동전"의 주인공으로, 다양한 성격 특성을 가지고 있습니다.
#
# 1. **정의감**: 홍길동은 불의에 반발하는 강한 정의감을 지니고 있습니다. 그는 부패한 관료와 권력을 비판하며, 약자들을 돕기 위해 적극적으로 나섭니다.
#
# 2. **지혜로움**: 여러 가지 어려운 상황에서도 지혜롭게 문제를 해결하는 모습을 보여주며, 뛰어난 전략과 계획으로 목표를 달성합니다.
#
# 3. **리더십**: 홍길동은 여러 사람을 이끄는 뛰어난 리더십을 가지고 있으며, 그의 리더십 아래에서 많은 사람들이 그를 따릅니다.
#
# 4. **불굴의 의지**: 역경 속에서도 포기하지 않고 끝까지 자신의 목표를 이루기 위해 노력합니다.
#
# 소설 "홍길동전"의 저자는 조선 시대의 문인 허균입니다. 허균은 여러 문학 작품을 통해 당시 사회 문제와 이상 사회에 대한 견해를 제시하였습니다. "홍길동전"은 그러한 그의 사상과 철학이 반영된 작품입니다.
# AI: 혹시 더 궁금한 점이 있으신가요? 홍길동이나 다른 주제에 대해 더 말씀드릴 수 있습니다. 질문이 있으면 언제든지 말씀해 주세요!
