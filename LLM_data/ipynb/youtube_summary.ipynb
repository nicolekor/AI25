# %%
# %pip install youtube-search

# %%
from youtube_search import YoutubeSearch

videos = YoutubeSearch("미국 대선", max_results=5).to_dict()
videos
# Out:
# [{'id': '4A3P9Tgm8wc',
#   'thumbnails': ['https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBiKa6FlGtJbPpVcHb4Nkfj_G7yqQ',
#    'https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA9dp_amuxkebdEB0E_Yg87rC4ZQA'],
#   'title': '[2020 미국 대선] 표 적게 받고도 대통령 된다? 복잡한 선거제도 6분 총정리 ❙ Won Less, but Elected Anyways? / 비디오머그',
#   'long_desc': None,
#   'channel': '비디오머그 - VIDEOMUG',
#   'duration': '5:50',
#   'views': '조회수 516,946회',
#   'publish_time': '4년 전',
#   'url_suffix': '/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoNIHCQmtCQGHKiGM7w%3D%3D'},
#  {'id': 'rY5_-jEUJYw',
#   'thumbnails': ['https://i.ytimg.com/vi/rY5_-jEUJYw/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBYYnU7eCb5PSpQCM3gDhOf1bt73g',
#    'https://i.ytimg.com/vi/rY5_-jEUJYw/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDcZRS4dfbO_u3K-XKj5S99g25Wiw'],
#   'title': '[LIVE] 2024 미국 대선 결과 분석 정리',
#   'long_desc': None,
#   'channel': '김지윤의 지식Play',
#   'duration': '1:25:34',
#   'views': '조회수 393,486회',
#   'publish_time': '스트리밍 시간: 9개월 전',
#   'url_suffix': '/watch?v=rY5_-jEUJYw&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'LKHzlzh7HBs',
#   'thumbnails': ['https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDeGBYbq18px6ES3r95qgC-rERrMg',
#    'https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB4q1lp3LRY4-ASZp-U0YU5Dqq9dw'],
#   'title': "🇺🇸[미국대선특집] 대통령 선거 제도 '선거인단'의 유래와 역사",
#   'long_desc': None,
#   'channel': '조승연의 탐구생활',
#   'duration': '15:33',
#   'views': '조회수 1,256,073회',
#   'publish_time': '4년 전',
#   'url_suffix': '/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'brHF-tV-p4Q',
#   'thumbnails': ['https://i.ytimg.com/vi/brHF-tV-p4Q/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLC2QHqhFN4-OJZOCnMjbgI54bRx_g',
#    'https://i.ytimg.com/vi/brHF-tV-p4Q/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDHgbKYbEWE5Q_5Vvz0f_BdwbRFZw'],
#   'title': '최다 득표하고도 패배할 수 있다...독특한 미 대선 방식 / YTN',
#   'long_desc': None,
#   'channel': ' YTN',
#   'duration': '1:58',
#   'views': '조회수 24,703회',
#   'publish_time': '9개월 전',
#   'url_suffix': '/watch?v=brHF-tV-p4Q&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'Rx3dYZPHGAQ',
#   'thumbnails': ['https://i.ytimg.com/vi/Rx3dYZPHGAQ/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDvv9e9lHeQWMp_ijzoLOvv7scXsA',
#    'https://i.ytimg.com/vi/Rx3dYZPHGAQ/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLATp6spTWH9Vtckyp3Y3WPCs3sEiQ'],
#   'title': "'선거인단·승자 독식'…핵심 키워드로 보는 미국 대선 / 연합뉴스TV (YonhapnewsTV)",
#   'long_desc': None,
#   'channel': '연합뉴스TV',
#   'duration': '2:42',
#   'views': '조회수 1,579회',
#   'publish_time': '9개월 전',
#   'url_suffix': '/watch?v=Rx3dYZPHGAQ&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'}]

# %%
video_url = 'http://youtube.com' + videos[3]['url_suffix']
video_url
# Out:
# 'http://youtube.com/watch?v=brHF-tV-p4Q&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'

# %%
# pip install youtube_transcript_api

# %%
# !pip install --upgrade youtube-transcript-api
# Out:
# Requirement already satisfied: youtube-transcript-api in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (1.2.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (from youtube-transcript-api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (from requests->youtube-transcript-api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc04-06\anaconda3\envs\my_llm\lib\site-packages (from requests->youtube-transcript-api) (2025.8.3)

# %%
from langchain_community.document_loaders import YoutubeLoader

loader = YoutubeLoader.from_youtube_url(
    video_url, 
    language=['ko', 'en'] # 자막 언어
)

loader.load()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       1 from langchain_community.document_loaders import YoutubeLoader
#       3 loader = YoutubeLoader.from_youtube_url(
#       4     video_url,
#       5     language=['ko', 'en'] # 자막 언어
#       6 )
# ----> 8 loader.load()
#
# File c:\Users\pc04-06\anaconda3\envs\my_llm\Lib\site-packages\langchain_community\document_loaders\youtube.py:262, in YoutubeLoader.load(self)
#     259     self._metadata.update(video_info)
#     261 try:
# --> 262     transcript_list = YouTubeTranscriptApi.list_transcripts(self.video_id)
#     263 except TranscriptsDisabled:
#     264     return []
#
# AttributeError: type object 'YouTubeTranscriptApi' has no attribute 'list_transcripts'
