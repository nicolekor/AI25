# %%
# 카페
# https://cafe.naver.com/hamminglab?iframe_url_utf8=%2FArticleRead.nhn%253Fclubid%3D22699177%2526articleid%3D22153%2526referrerAllArticles%3Dtrue

# !pip install PyQt5
# !pip install kivy

# !pip install kivy[full]

# %%
import tkinter as tk

# 창 생성
window = tk.Tk()
window.title("나의 첫 번째 윈도우 창")
window.geometry("400x300")  # 가로 400, 세로 300

# 라벨 추가
label = tk.Label(window, text="Hello, Python GUI!", font=("Arial", 16))
label.pack(pady=20)

# 윈도우 실행
window.mainloop()

# %%
from PyQt5.QtWidgets import QApplication, QLabel, QWidget

app = QApplication([])
window = QWidget()
window.setWindowTitle('PyQt5 예제')
label = QLabel('안녕하세요 PyQt5!', parent=window)
window.resize(300, 200)
window.show()
app.exec_()
# Out:
# 0

# %%
import wx

app = wx.App(False)
frame = wx.Frame(None, wx.ID_ANY, "wxPython 예제")
frame.Show(True)
app.MainLoop()
