# %%
# !pip install opencv-python

# %%
import numpy as np
import cv2

def onChange(value):												# 트랙바 콜백 함수
    global image                        	# 전역 변수 참조

    add_value = value - int(image[0][0])        	# 트랙바 값과 영상 화소값 차분
    print("추가 화소값:", add_value)
    if  add_value > 0 : image = image + add_value            		# 행렬과 스칼라 덧셈 수행
    else: image = image - abs(add_value)  # 행렬과 스칼라 덧셈 수행
    cv2.imshow(title, image)

image = np.zeros((300, 500), np.uint8)           	# 영상 생성

title = 'Trackbar Event'
cv2.imshow(title, image)

cv2.createTrackbar("Brightness", title, image[0][0], 255, onChange)	# 트랙바 콜백 함수 등록
cv2.waitKey(0)
cv2.destroyWindow(title)
# Out:
# 추가 화소값: 1
# 추가 화소값: 1
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 1
# 추가 화소값: 3
# 추가 화소값: 5
# 추가 화소값: 5
# 추가 화소값: 3
# 추가 화소값: 6
# 추가 화소값: 4
# 추가 화소값: 2
# 추가 화소값: 1
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 2
# 추가 화소값: 2
# 추가 화소값: 4
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 5
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 2
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 3
# 추가 화소값: 5
# 추가 화소값: 10
# 추가 화소값: 6
# 추가 화소값: 6
# 추가 화소값: 6
# 추가 화소값: 5
# 추가 화소값: 3
# 추가 화소값: 4
# 추가 화소값: 2
# 추가 화소값: 2
# 추가 화소값: 3
# 추가 화소값: 4
# 추가 화소값: 5
# 추가 화소값: 3
# 추가 화소값: 5
# 추가 화소값: 3
# 추가 화소값: 1
# 추가 화소값: 3
# 추가 화소값: 4
# 추가 화소값: 4
# 추가 화소값: 2
# 추가 화소값: 1
# 추가 화소값: -5
# 추가 화소값: -4
# 추가 화소값: -5
# 추가 화소값: -4
# 추가 화소값: -16
# 추가 화소값: -7
# 추가 화소값: -8
# 추가 화소값: -6
# 추가 화소값: -4
# 추가 화소값: -6
# 추가 화소값: -5
# 추가 화소값: -6
# 추가 화소값: -4
# 추가 화소값: -2
# 추가 화소값: -4
# 추가 화소값: -3
# 추가 화소값: -2
# 추가 화소값: -1
# 추가 화소값: -4
# 추가 화소값: -3
# 추가 화소값: -2
# 추가 화소값: -4
# 추가 화소값: -2
# 추가 화소값: -4
# 추가 화소값: -4
# 추가 화소값: -6
# 추가 화소값: -3
# 추가 화소값: -5
# 추가 화소값: -7
# 추가 화소값: -5
# 추가 화소값: -8
# 추가 화소값: -4
# 추가 화소값: -4
# 추가 화소값: -5
# 추가 화소값: -3
# 추가 화소값: -2
# 추가 화소값: 2
# 추가 화소값: 11
# 추가 화소값: 13
# 추가 화소값: 16
# 추가 화소값: 15
# 추가 화소값: 20
# 추가 화소값: 16
# 추가 화소값: 15
# 추가 화소값: 18
# 추가 화소값: 21
# 추가 화소값: 16
# 추가 화소값: 14
# 추가 화소값: 12
# 추가 화소값: 13
# 추가 화소값: 12
# 추가 화소값: 10
# 추가 화소값: -3
# 추가 화소값: -39
# 추가 화소값: -35
# 추가 화소값: -39
# 추가 화소값: -36
# 추가 화소값: -29
# 추가 화소값: -26
# 추가 화소값: -26
# 추가 화소값: -22
# 추가 화소값: 5
# 추가 화소값: 5
# 추가 화소값: 4
# 추가 화소값: 5
# 추가 화소값: 3
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 20
#      18 cv2.createTrackbar("Brightness", title, image[0][0], 255, onChange)	# 트랙바 콜백 함수 등록
#      19 cv2.waitKey(0)
# ---> 20 cv2.destroyWindow(title)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:1261: error: (-27:Null pointer) NULL window: 'Trackbar Event' in function 'cvDestroyWindow'
