# %%
# !pip install keras

# %%
import keras
keras.config.backend()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import keras
#       2 keras.config.backend()
#
# File c:\Users\pc04-18\anaconda3\envs\dana\Lib\site-packages\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#       9 from keras import applications as applications
#
# File c:\Users\pc04-18\anaconda3\envs\dana\Lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File c:\Users\pc04-18\anaconda3\envs\dana\Lib\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
# ...

# %%
import pandas as pd
import numpy as np

# %%
import os 
os.environ["KERAS_BACKEND"] = "torch"

# %%
keras.config.backend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 keras.config.backend()
#
# NameError: name 'keras' is not defined
