# %%
import pandas as pd 
import numpy as np 
import scipy

# %%
# p173

# K 평균 클러스터링 모델

# 실습에 필요한 라이브러리를 불러옵니다.
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# 3개의 클러스터로 분류할 임의의 데이터세트를 만듭니다.
X = np.array([[1.2, 1.3], [1.1, 1.0], [0.8, 1.1],
              [4.5, 4.4], [4.0, 4.5], [4.8, 3.9],
              [9.9, 9.8], [8.9, 9.5], [9.2, 9.1]])

# K-평균 클러스터링 알고리즘을 이용해 모델을 학습시킵니다.
model = KMeans(n_clusters=3, random_state=0)
model.fit(X)

# 데이터 샘플들이 각각 어떤 클러스터로 분류되었는지 확인합니다.
print(model.labels_)

# 데이터 분포를 시각화하기 위해 산점도 그래프를 그립니다.
plt.scatter(X[:, 0], X[:, 1], c=model.labels_, cmap='brg')
plt.show()

# 새로운 데이터 샘플을 추가합니다.
X_test = np.array([[4.4, 4.0], [8.9, 7.8]])

# 데이터 분포를 시각화하기 위해 산점도 그래프를 그립니다.
plt.scatter(X[:, 0], X[:, 1], c=model.labels_, cmap='brg')
plt.scatter(X_test[:, 0], X_test[:, 1], color='orange')
plt.show()

# 새로운 데이터 샘플에 대한 추론을 실행하고 결과를 확인합니다.
result = model.predict(X_test)
print('새로운 데이터 샘플이 속하는 클러스터 추론: {}'.format(result))
# Out:
# [2 2 2 0 0 0 1 1 1]
# c:\Users\pc04-06\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# 새로운 데이터 샘플이 속하는 클러스터 추론: [0 1]

# %%
# 176 까지
